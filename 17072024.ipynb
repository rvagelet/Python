# %% [markdown]
# <a href="https://colab.research.google.com/github/rvagelet/Python/blob/main/17072024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Vamos a cargar un DataFrame a partir de un fichero de excel
#Ventas_groucery, para poder leer excels primero necesitamos instalar la libreria openpyxl

# %%
# !pip install openpyxl

# %%
# !python --version
# Out:
# Python 3.10.12

# %%
# !apt-get install python3.12
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# python3.12 is already the newest version (3.12.4-1+jammy1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.

# %%
# !python3.12 --version
# Out:
# Python 3.12.4

# %%
import pandas as pd
agosto2014 = pd.read_excel(r"/content/VentasGroucery_Meses.xlsx") #li podem posar ,0 #podem no posar-li, com vulguem
agosto2014
# Out:
#     Order ID                           Product        Category  Unit Price  \
# 0      10248     Singaporean Hokkien Fried Mee  Grains/Cereals         9.8
# 1      10248            Mozzarella di Giovanni  Dairy Products        34.8
# 2      10248                    Queso Cabrales  Dairy Products        14.0
# 3      10249                              Tofu         Produce        18.6
# 4      10249             Manjimup Dried Apples         Produce        42.4
# 5      10250  Louisiana Fiery Hot Pepper Sauce      Condiments        16.8
# 6      10250   Jack's New England Clam Chowder         Seafood         7.7
# 7      10250             Manjimup Dried Apples         Produce        42.4
# 8      10251  Louisiana Fiery Hot Pepper Sauce      Condiments        16.8
# 9      10251               Gustaf's Knäckebröd  Grains/Cereals        16.8
# 10     10251                    Ravioli Angelo  Grains/Cereals        15.6
# ...

# %%
import pandas as pd
septiembre2014 = pd.read_excel(r"/content/VentasGroucery_Meses.xlsx",1)  #posant-li el número després de la coma, obre la pastenya per l'ordre que va
sheet_name="Ventas Septiembre 2014"
septiembre2014
# Out:
#     Order ID                 Product        Category  Unit Price  Quantity  \
# 0      10270             Ipoh Coffee       Beverages        36.8        25
# 1      10270             Inlagd Sill         Seafood        15.2        30
# 2      10271                 Geitost  Dairy Products         2.0        24
# 3      10272  Sir Rodney's Marmalade     Confections        64.8         6
# 4      10272       Gorgonzola Telino  Dairy Products        10.0        40
# ..       ...                     ...             ...         ...       ...
# 64     10294       Camembert Pierrot  Dairy Products        27.2        21
# 65     10294    Rhönbräu Klosterbier       Beverages         6.2         6
# 66     10294             Ipoh Coffee       Beverages        36.8        15
# 67     10294            Alice Mutton    Meat/Poultry        31.2        15
# 68     10294                    Chai       Beverages        14.4        18
#
#                       Customer    Ship City Ship Country Order Date
# ...

# %%
#Como anexar 2 DataFrames para obtener uno solo con todos los registros
#Anexar significa poner filas una debajo de otras, tienen que tener la misma estructura,
#el mismo numero de columnas y campos, y con los mismos nombres

#aprenderemos a cambiar los nombres por si acaso

dosmeses = pd.concat([agosto2014, septiembre2014], ignore_index=True)
dosmeses

#Entorno de ejecucion, reiniciar sesion y ejectuar todo
# Out:
#      Order ID                        Product        Category  Unit Price  \
# 0       10248  Singaporean Hokkien Fried Mee  Grains/Cereals         9.8
# 1       10248         Mozzarella di Giovanni  Dairy Products        34.8
# 2       10248                 Queso Cabrales  Dairy Products        14.0
# 3       10249                           Tofu         Produce        18.6
# 4       10249          Manjimup Dried Apples         Produce        42.4
# ..        ...                            ...             ...         ...
# 123     10294              Camembert Pierrot  Dairy Products        27.2
# 124     10294           Rhönbräu Klosterbier       Beverages         6.2
# 125     10294                    Ipoh Coffee       Beverages        36.8
# 126     10294                   Alice Mutton    Meat/Poultry        31.2
# 127     10294                           Chai       Beverages        14.4
#
#      Quantity                    Customer    Ship City Ship Country Order Date
# ...

# %%
#Practica 1: Partiendo del excel Ventas_Groucery_Meses.xlsx, cargar en tres DataFrames los
#datos correspondientes a los tres meses y realizar los pasos necesarios para resolver los siguientes
#enunciados
#Juntar los 3 DataFrames en 1 llamado trimestre
#Crear la columna Amount = Unit Price * Quantity
#Crear una columna llamada Enterprise con el valor "Enterprise One"
#Ver en un texto el promedio de Amount de los pedidos cuya Category = Beverages

# %%
import pandas as pd
octubre2014 = pd.read_excel(r"/content/VentasGroucery_Meses.xlsx",2)  #posant-li el número després de la coma, obre la pastenya per l'ordre que va
sheet_name="Ventas Octubre 2014"
octubre2014

trimestre = pd.concat([agosto2014, septiembre2014, octubre2014], ignore_index=True)
trimestre
# Out:
#      Order ID                          Product        Category  Unit Price  \
# 0       10248    Singaporean Hokkien Fried Mee  Grains/Cereals         9.8
# 1       10248           Mozzarella di Giovanni  Dairy Products        34.8
# 2       10248                   Queso Cabrales  Dairy Products        14.0
# 3       10249                             Tofu         Produce        18.6
# 4       10249            Manjimup Dried Apples         Produce        42.4
# ..        ...                              ...             ...         ...
# 180     10315                    Sasquatch Ale       Beverages        11.2
# 181     10315                    Outback Lager       Beverages        12.0
# 182     10316  Jack's New England Clam Chowder         Seafood         7.7
# 183     10316                   Tarte au sucre     Confections        39.4
# 184     10317                             Chai       Beverages        14.4
#
# ...

# %%
trimestre['Amount']=trimestre['Unit Price'] * trimestre['Quantity']    #del meu DataFrame(taula)agafem la columna tal i com està
trimestre
# Out:
#      Order ID                          Product        Category  Unit Price  \
# 0       10248    Singaporean Hokkien Fried Mee  Grains/Cereals         9.8
# 1       10248           Mozzarella di Giovanni  Dairy Products        34.8
# 2       10248                   Queso Cabrales  Dairy Products        14.0
# 3       10249                             Tofu         Produce        18.6
# 4       10249            Manjimup Dried Apples         Produce        42.4
# ..        ...                              ...             ...         ...
# 180     10315                    Sasquatch Ale       Beverages        11.2
# 181     10315                    Outback Lager       Beverages        12.0
# 182     10316  Jack's New England Clam Chowder         Seafood         7.7
# 183     10316                   Tarte au sucre     Confections        39.4
# 184     10317                             Chai       Beverages        14.4
#
# ...

# %%
trimestre['Enterprise']='EnterpriseOne'    #del meu DataFrame assigna-li un valor (es fixe perquè és per a totes)
trimestre
# Out:
#      Order ID                          Product        Category  Unit Price  \
# 0       10248    Singaporean Hokkien Fried Mee  Grains/Cereals         9.8
# 1       10248           Mozzarella di Giovanni  Dairy Products        34.8
# 2       10248                   Queso Cabrales  Dairy Products        14.0
# 3       10249                             Tofu         Produce        18.6
# 4       10249            Manjimup Dried Apples         Produce        42.4
# ..        ...                              ...             ...         ...
# 180     10315                    Sasquatch Ale       Beverages        11.2
# 181     10315                    Outback Lager       Beverages        12.0
# 182     10316  Jack's New England Clam Chowder         Seafood         7.7
# 183     10316                   Tarte au sucre     Confections        39.4
# 184     10317                             Chai       Beverages        14.4
#
# ...

# %%
FBeverage = trimestre['Category']=="Beverages"
print(round(trimestre[FBeverage]['Amount'].mean(),2))
# Out:
# 348.87

# %%
#con el comando iloc se pueden reordenar las columnas
#izquierda de los dos puntos, filas
#derecha, columnas
trimestre.iloc[:,[0,1,2,3,4,9,5,6,7,8]]
# Out:
#      Order ID                          Product        Category  Unit Price  \
# 0       10248    Singaporean Hokkien Fried Mee  Grains/Cereals         9.8
# 1       10248           Mozzarella di Giovanni  Dairy Products        34.8
# 2       10248                   Queso Cabrales  Dairy Products        14.0
# 3       10249                             Tofu         Produce        18.6
# 4       10249            Manjimup Dried Apples         Produce        42.4
# ..        ...                              ...             ...         ...
# 180     10315                    Sasquatch Ale       Beverages        11.2
# 181     10315                    Outback Lager       Beverages        12.0
# 182     10316  Jack's New England Clam Chowder         Seafood         7.7
# 183     10316                   Tarte au sucre     Confections        39.4
# 184     10317                             Chai       Beverages        14.4
#
# ...

# %% [markdown]
# Si les columnes tenen noms diferent si no coincideixen faran més d'una columna

# %%
#Antes de hacer concat debo cambiar los nombres
#deberíamos cambiar los nombres de las columnas necesarias
#Opcion A (la mas usada)

agosto2014 = agosto2014.rename(columns={'Categoria':'Category', 'Ciudad':'Ship City'})
agosto2014
# Out:
#     Order ID                           Product        Category  Unit Price  \
# 0      10248     Singaporean Hokkien Fried Mee  Grains/Cereals         9.8
# 1      10248            Mozzarella di Giovanni  Dairy Products        34.8
# 2      10248                    Queso Cabrales  Dairy Products        14.0
# 3      10249                              Tofu         Produce        18.6
# 4      10249             Manjimup Dried Apples         Produce        42.4
# 5      10250  Louisiana Fiery Hot Pepper Sauce      Condiments        16.8
# 6      10250   Jack's New England Clam Chowder         Seafood         7.7
# 7      10250             Manjimup Dried Apples         Produce        42.4
# 8      10251  Louisiana Fiery Hot Pepper Sauce      Condiments        16.8
# 9      10251               Gustaf's Knäckebröd  Grains/Cereals        16.8
# 10     10251                    Ravioli Angelo  Grains/Cereals        15.6
# ...

# %%
#opcion B (mejor opcion que la A)
#Si sé que la hoja de octubre tiene las columnas correctas puedo copiarlas en otra hoja fast & furious)
#Tengo que tener la certeza de que estña bien esa hoja!
agosto2014.columns = octubre2014.columns
agosto2014
# Out:
#     Order ID                           Product        Category  Unit Price  \
# 0      10248     Singaporean Hokkien Fried Mee  Grains/Cereals         9.8
# 1      10248            Mozzarella di Giovanni  Dairy Products        34.8
# 2      10248                    Queso Cabrales  Dairy Products        14.0
# 3      10249                              Tofu         Produce        18.6
# 4      10249             Manjimup Dried Apples         Produce        42.4
# 5      10250  Louisiana Fiery Hot Pepper Sauce      Condiments        16.8
# 6      10250   Jack's New England Clam Chowder         Seafood         7.7
# 7      10250             Manjimup Dried Apples         Produce        42.4
# 8      10251  Louisiana Fiery Hot Pepper Sauce      Condiments        16.8
# 9      10251               Gustaf's Knäckebröd  Grains/Cereals        16.8
# 10     10251                    Ravioli Angelo  Grains/Cereals        15.6
# ...

# %%
trimestre['Category'].unique()
# Out:
# array(['Grains/Cereals', 'Dairy Products', 'Produce', 'Condiments',
#        'Seafood', 'Confections', 'Beverages', 'Meat/Poultry'],
#       dtype=object)

# %%
#Ahora vamos a ver el Amount*Category  #sumar la cantidad por categorias
trimestre.groupby(['Category'])['Amount'].sum()
# Out:
# Category
# Beverages         13606.0
# Condiments         6375.6
# Confections       17936.3
# Dairy Products    16594.0
# Grains/Cereals     2275.2
# Meat/Poultry      11067.9
# Produce            6141.0
# Seafood           10353.3
# Name: Amount, dtype: float64

# %%
#para tener mas de uan columna podemos poner más de un parámetro
#Si queremos que nos aparezcan diferente deberemos ordenarlos como nos interese

trimestre.groupby(['Category','Ship Country'])['Amount'].sum()
# Out:
# Category   Ship Country
# Beverages  Austria          860.8
#            Belgium          441.6
#            Brazil          1356.8
#            Finland          920.0
#            France          1104.0
#                             ...
# Seafood    Mexico          1040.8
#            Spain            919.2
#            Sweden           492.5
#            Switzerland      380.0
#            USA             1645.0
# Name: Amount, Length: 83, dtype: float64

# %%
trimestreagroup = trimestre.groupby(['Category'])['Amount'].count()    #cuantas lineas hay que pertenecen a la categoria
trimestreagroup
# Out:
# Category
# Beverages         39
# Condiments        19
# Confections       30
# Dairy Products    35
# Grains/Cereals    11
# Meat/Poultry      15
# Produce           10
# Seafood           26
# Name: Amount, dtype: int64

# %%
#Vamos a almacenar la agrupación por categoria
trimestreagroup = trimestre.groupby(['Category'])['Amount'].sum()
trimestreagroup    #esto es una agrupacion que nos lo muestra en la salida
#vamos a convertir esta agrupacion en un DataFrame
DFtrimestregrup = pd.DataFrame(trimestreagroup, columns=['Amount'])
DFtrimestregrup.info()
DFtrimestregrup
#Al convertir la agrupacion en un DataFrame, el campo category lo considera un indice
#Ahora haremos reset_index para conseguir hacer un reset nuevo, para que Category pase a ser un campo
DFtrimestregrup = DFtrimestregrup.reset_index()
DFtrimestregrup

#Vamos a guardar en un fichero el DataFrame hecho
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, Beverages to Seafood
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Amount  8 non-null      float64
# dtypes: float64(1)
# memory usage: 128.0+ bytes
#          Category   Amount
# 0       Beverages  13606.0
# 1      Condiments   6375.6
# 2     Confections  17936.3
# 3  Dairy Products  16594.0
# 4  Grains/Cereals   2275.2
# 5    Meat/Poultry  11067.9
# 6         Produce   6141.0
# 7         Seafood  10353.3

# %%
#para guardar el DataFrame de un fichero en .csv
#es guardarà a dins del colab, ho descarregarem i ho posarem a la carpeta que vulguem
DFtrimestregrup.to_csv("trimestre2014.csv",sep=",",index=False)
#index=false no me va a mostrar la indexacion
#sep= separador coma

# %%
#Per a guardar el fitxer a l'excel
#con to_excel, especificando el nombre de la hoja, ajustar si queremos que pase las cabeceras (los nombres de los campos)
#y si queremos los indices, index=True
DFtrimestregrup.to_excel("trimestre2014.xlsx",sheet_name="Amount Category",header=True,index=False)

#.csv es lo mas ligerito,esta bien usarlo por el peso (aunque la diferencia no es muy grande)

# %%
#Ahora vamos a comenzar con los graficos. Análisi de datos.
#Conectar con datos
#Transformar y calcular datos
#Ver los datos (gráficos). Se utilizan otras interfícies para ver los gráficos. Hay cosas que no puedes hacer y es mas
#complicado que no usar otros programas
#Powerview (explorar, visualizar y presentar los datos)
#Las tripas si que se hacen con Python

# %%
#Gráficos en Python
#Matplotlib (la + usada sin ningun tipo de duda)
#Seaborn (gráficos de alta calidad)
#Por lo tanto, primero tenemos que instalar la librería, es decir pip install matplotlib

# %%
# !pip install matplotlib

# %%
#llamar a la librería matplotlib, .pyplot es una clase dentro de la libreria
import matplotlib.pyplot as plt
#crearemos la figura, reservar espacio en el kernel para hacer una representacion grafica.
#creame una figura que se llame ax
fig, ax=plt.subplots()    #todo lo que sea con "s" son colecciones, plural es una coleccion
                          #subplots me permitirá ver una serie de graficos que queremos ver.
#grafico circular (de quesitos) es el grafico "pie", el primer parámetro es la metrica(tiempo), es decir el AMOUNT,
#despues en las #metrica=amount
#etiquetas (labels) tendria la dimension (diferentes categorias:zona, familia de producto, vendedor). #label=Category
#un parametro

ax.pie(DFtrimestregrup['Amount'],labels=DFtrimestregrup['Category'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Aparte de que me salga el quesito, quiero que me salga el %: el parametro autopct
import matplotlib.pyplot as plt
fig, ax=plt.subplots()
ax.pie(DFtrimestregrup['Amount'],labels=DFtrimestregrup['Category'], autopct="%.1f%%",pctdistance=1.4)
plt.show

#pctdistance
#labeldistance
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Grafico de columnas. Llamaremos a matplotlib
import matplotlib.pyplot as plt
#el grafico de columnas seria tipo bar, reservar espacio para la figura
fig, pepe=plt.subplots()
#primero la dimensión y después la métrica
bars = pepe.bar(DFtrimestregrup['Category'],DFtrimestregrup['Amount'], color='green')
#con bars podremos hacer configuraciones más
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Grafico de columnas. Llamaremos a matplotlib
import matplotlib.pyplot as plt
#el grafico de columnas seria tipo bar, reservar espacio para la figura
fig, pepe=plt.subplots()
#primero la dimensión y después la métrica
bars = pepe.bar(DFtrimestregrup['Category'],DFtrimestregrup['Amount'], color='green')
#con bars podremos hacer configuraciones más
#vamos a configurar los ejes antes de imprimir
pepe.set_xlabel('Categorias')
plt.xticks(rotation=60)    #para poner las etiquetas rotadas en el eje x
pepe.set_ylabel('Importe')
#título del gráfico
pepe.set_title('Ventas por categoría')
#mostrar la leyenda
pepe.legend(['Color'])
#mostrar el importe de las barras, tendremos que recorrer todas las barras
for b in pepe.patches:     #This loop iterates through each bar (patch) in your bar chart object pepe.
  pepe.annotate(format(b.get_height(), '.2f'),    #Gets the height (numerical value) of the current bar.
                   (b.get_x() + b.get_width() / 2,   #Calculates the coordinates for the center of the top of the bar.
                    b.get_height()), ha='center', va='center',   #Ensures the text is horizontally and vertically centered above the bar.
                   xytext=(0, 8),    #Offsets the text slightly above the bar (8 points).
                   textcoords='offset points')   #Specifies that the offset is in points.
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
